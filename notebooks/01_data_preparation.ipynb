# %% [markdown]
# # 📊 Data Preparation - AI-Generated Image Detection
#
# **Project:** Truth in Pixels - Detecting AI-Generated Images Beyond Faces
# **Team Member 1:** Data Preparation Specialist
# **Objective:** Explore, preprocess, and prepare the dataset for training
#
# ## 🎯 Notebook Overview
#
# This notebook handles all aspects of data preparation for our AI-generated image detection project:
#
# 1. **Environment Setup** - Configure libraries and reproducibility
# 2. **Dataset Loading** - Download and explore the Hugging Face dataset
# 3. **Exploratory Data Analysis** - Understand data distribution and characteristics
# 4. **Data Preprocessing** - Implement transforms and augmentation strategies
# 5. **Dataset Splitting** - Create train/validation/test splits
# 6. **Data Quality Assessment** - Validate data integrity and class balance
#
# ---

# %% [markdown]
# # 01 - Data Preparation and Exploratory Data Analysis
#
# **Team Members:** Marston Ward, Jasper Dolar, Victor Salcedo
# **Project:** AI-Generated vs Real Image Classification
# **Date:** November 2025
#
# ---
#
# ## Overview
#
# This notebook performs **data loading, exploration, and preparation** for training deep learning models to classify images as either **real** or **AI-generated**.
#
# ### Dataset
# - **Source:** Hugging Face (`Hemg/AI-Generated-vs-Real-Images-Datasets`)
# - **Labels:**
#   - `0` = Real photograph
#   - `1` = AI-generated image
#
# ### What This Notebook Does
# 1. ✅ Load dataset from Hugging Face
# 2. ✅ Explore class distribution and sample images
# 3. ✅ Define image transformations and augmentations
# 4. ✅ Split data into train/validation/test sets (80/10/10)
# 5. ✅ Create PyTorch DataLoaders for efficient batch processing
#
# ### Next Steps
# After running this notebook, proceed to:
# - **02_model_training.ipynb** - Train CNN, ResNet50, and EfficientNet-B2 models
# - **03_evaluation_comparison.ipynb** - Compare model performance
#
# ---

# %% [markdown]
# ## 1. Setup and Imports
#
# Install required packages and configure the environment for GPU acceleration.

# %%
# %%time
# Import standard libraries
import os
import random

# Import data science libraries
import matplotlib.pyplot as plt
import numpy as np

# Import PyTorch libraries
import torch
import torch.nn as nn
import torchvision
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

# Import Hugging Face datasets
from datasets import load_dataset

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🖥️  Using device: {device}")
if device.type == "cuda":
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
    
print(f"✅ Environment configured with seed {SEED}")

# %% [markdown]
# ## 2. Load Dataset from Hugging Face
#
# Load the AI-Generated vs Real Images dataset directly from Hugging Face.
# No manual downloads needed - Hugging Face handles caching automatically.

# %%
# %%time
# Load dataset from Hugging Face
print("📥 Loading dataset from Hugging Face...")
dataset = load_dataset("Hemg/AI-Generated-vs-Real-Images-Datasets")

# Display dataset structure
print("\n📊 Dataset Structure:")
print(dataset)
print(f"\n✅ Total training samples: {len(dataset['train']):,}")

# %% [markdown]
# ## 3. Exploratory Data Analysis (EDA)
#
# ### 3.1 Inspect Sample Data

# %%
# View a single sample
sample = dataset['train'][0]
print(f"Sample keys: {sample.keys()}")
print(f"Label: {sample['label']} ({'AI-Generated' if sample['label'] == 1 else 'Real'})")
print(f"Image shape: {sample['image'].size}")

# Display sample image
plt.figure(figsize=(6, 6))
plt.imshow(sample['image'])
plt.title(f"Sample: {'AI-Generated' if sample['label'] == 1 else 'Real'}", fontsize=14, fontweight='bold')
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.2 Class Distribution Analysis

# %%
# Analyze class distribution
labels = [item['label'] for item in dataset['train']]
unique, counts = np.unique(labels, return_counts=True)

print("📊 Class Distribution:")
for label, count in zip(unique, counts):
    class_name = "Real" if label == 0 else "AI-Generated"
    percentage = (count / len(labels)) * 100
    print(f"   {class_name}: {count:,} images ({percentage:.1f}%)")

# Visualize distribution
plt.figure(figsize=(8, 5))
colors = ['#3498db', '#e74c3c']
bars = plt.bar(['Real', 'AI-Generated'], counts, color=colors, edgecolor='black', linewidth=1.5)
plt.title('Class Distribution', fontsize=16, fontweight='bold')
plt.xlabel('Class', fontsize=12)
plt.ylabel('Number of Images', fontsize=12)
plt.grid(axis='y', alpha=0.3)

# Add count labels on bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Visual Comparison: Real vs AI-Generated

# %%
# Separate real and AI-generated samples
real_samples = [x['image'] for x in dataset['train'] if x['label'] == 0]
ai_samples = [x['image'] for x in dataset['train'] if x['label'] == 1]

print(f"Real images: {len(real_samples):,}")
print(f"AI-generated images: {len(ai_samples):,}")

# Display 4 real and 4 AI-generated images
fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i in range(4):
    # Real images (top row)
    axes[0, i].imshow(random.choice(real_samples))
    axes[0, i].set_title('Real', fontsize=12, fontweight='bold', color='#3498db')
    axes[0, i].axis('off')
    
    # AI-generated images (bottom row)
    axes[1, i].imshow(random.choice(ai_samples))
    axes[1, i].set_title('AI-Generated', fontsize=12, fontweight='bold', color='#e74c3c')
    axes[1, i].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Image Transformations
#
# Define preprocessing pipelines for training and evaluation.
#
# ### Training Transformations
# - Resize to 224×224 (standard CNN input)
# - Random horizontal flips (data augmentation)
# - Random rotations (±10 degrees)
# - Color jittering (brightness, contrast, saturation)
# - Normalization using ImageNet statistics
#
# ### Validation/Test Transformations
# - Resize to 224×224
# - Normalization only (no augmentation)

# %%
# Image dimensions and normalization constants
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

# Training transformations (with augmentation)
train_transforms = transforms.Compose([
    transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
    transforms.Lambda(lambda img: img.convert("RGB")),  # Ensure 3 channels
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(
        brightness=0.1,
        contrast=0.1,
        saturation=0.1,
        hue=0.05
    ),
    transforms.ToTensor(),
    transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)
])

# Validation/Test transformations (no augmentation)
val_transforms = transforms.Compose([
    transforms.Resize((IMG_HEIGHT, IMG_WIDTH)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD)
])

print("✅ Transformations defined:")
print(f"   • Image size: {IMG_HEIGHT}×{IMG_WIDTH}")
print(f"   • Normalization: ImageNet statistics")
print(f"   • Training augmentation: Enabled")

# %% [markdown]
# ## 5. Dataset Preparation
#
# ### 5.1 Create Custom Dataset Class

# %%
class HuggingFaceImageDataset(Dataset):
    """
    Custom PyTorch Dataset for Hugging Face images.
    
    Args:
        images: List of PIL images
        labels: List of corresponding labels (0=Real, 1=AI-Generated)
        transform: Optional torchvision transforms
    """
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image = self.images[idx]
        label = self.labels[idx]
        
        if self.transform:
            image = self.transform(image)
        
        return image, label

print("✅ Custom Dataset class defined")

# %% [markdown]
# ### 5.2 Split Dataset (80% Train, 10% Val, 10% Test)

# %%
# %%time
# Extract images and labels
images = [x['image'] for x in dataset['train']]
labels = [x['label'] for x in dataset['train']]

# Shuffle dataset for random splits
combined = list(zip(images, labels))
random.shuffle(combined)
images, labels = zip(*combined)

# Calculate split indices
total_size = len(images)
train_end = int(0.8 * total_size)
val_end = int(0.9 * total_size)

# Split data
train_images = images[:train_end]
val_images = images[train_end:val_end]
test_images = images[val_end:]

train_labels = labels[:train_end]
val_labels = labels[train_end:val_end]
test_labels = labels[val_end:]

print("📊 Dataset Split:")
print(f"   • Training:   {len(train_images):,} images ({len(train_images)/total_size*100:.1f}%)")
print(f"   • Validation: {len(val_images):,} images ({len(val_images)/total_size*100:.1f}%)")
print(f"   • Test:       {len(test_images):,} images ({len(test_images)/total_size*100:.1f}%)")
print(f"   • Total:      {total_size:,} images")

# %% [markdown]
# ### 5.3 Create PyTorch Datasets and DataLoaders

# %%
# Create datasets
train_dataset = HuggingFaceImageDataset(train_images, train_labels, transform=train_transforms)
val_dataset = HuggingFaceImageDataset(val_images, val_labels, transform=val_transforms)
test_dataset = HuggingFaceImageDataset(test_images, test_labels, transform=val_transforms)

# Create data loaders
BATCH_SIZE = 32

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

print("✅ DataLoaders created:")
print(f"   • Batch size: {BATCH_SIZE}")
print(f"   • Training batches: {len(train_loader)}")
print(f"   • Validation batches: {len(val_loader)}")
print(f"   • Test batches: {len(test_loader)}")

# %% [markdown]
# ## 6. Verify Data Pipeline
#
# Display a batch of augmented training images to confirm transformations are working correctly.

# %%
def denormalize_image(img_tensor):
    """Reverse ImageNet normalization for visualization."""
    mean = np.array(IMAGENET_MEAN)
    std = np.array(IMAGENET_STD)
    img = img_tensor.numpy().transpose((1, 2, 0))
    img = std * img + mean
    img = np.clip(img, 0, 1)
    return img

# Get one batch
dataiter = iter(train_loader)
sample_images, sample_labels = next(dataiter)

# Display 8 images
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()

for i in range(8):
    img = denormalize_image(sample_images[i].cpu())
    label = sample_labels[i].item()
    class_name = 'AI-Generated' if label == 1 else 'Real'
    color = '#e74c3c' if label == 1 else '#3498db'
    
    axes[i].imshow(img)
    axes[i].set_title(class_name, fontsize=12, fontweight='bold', color=color)
    axes[i].axis('off')

plt.suptitle('Sample Training Batch (After Augmentation)', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

print("✅ Data pipeline verified - images loading correctly with augmentation")

# %% [markdown]
# ## 7. Summary
#
# ### ✅ Completed Tasks
# 1. ✅ Loaded dataset from Hugging Face (`Hemg/AI-Generated-vs-Real-Images-Datasets`)
# 2. ✅ Performed exploratory data analysis (EDA)
# 3. ✅ Analyzed class distribution (balanced dataset)
# 4. ✅ Defined image transformations with augmentation
# 5. ✅ Split data into train/validation/test sets (80/10/10)
# 6. ✅ Created PyTorch DataLoaders for batch processing
# 7. ✅ Verified data pipeline with sample visualizations
#
# ### 📊 Dataset Statistics
# The dataset will be split as:
# - **Training:** ~80% of images
# - **Validation:** ~10% of images
# - **Test:** ~10% of images
# - **Classes:** 2 (Real, AI-Generated)
# - **Image Size:** 224×224×3 (RGB)
#
# ### 🔄 Ready for Next Step
# The data is now prepared and ready for model training.
#
# **Next Notebook:** `02_model_training.ipynb`
# - Train custom CNN model
# - Train ResNet50 with transfer learning
# - Train EfficientNet-B2 with transfer learning
# - Save best models for evaluation

# %%
# Environment Setup and Library Imports - Cross Platform Compatible
import os
import sys
import warnings
warnings.filterwarnings('ignore')

# Detect platform and setup accordingly
def detect_platform():
    """Detect if running on Colab or local machine"""
    try:
        import google.colab
        return "colab"
    except ImportError:
        return "local"

platform = detect_platform()
print(f"🔍 Running on: {platform}")

# Add project root to path
if platform == "colab":
    # For Colab - project should be in current directory
    project_root = "/content/AAI-521-Computer-Vision-Image-Classification-Project"
    if not os.path.exists(project_root):
        print("❌ Repository not found. Please run the Colab setup notebook first!")
        print("📖 Open: notebooks/00_colab_setup.ipynb")
    else:
        os.chdir(project_root)
        sys.path.insert(0, project_root)
else:
    # For local - navigate to project root
    project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
    if project_root not in sys.path:
        sys.path.insert(0, project_root)

print(f"📁 Project root: {project_root}")

# Core libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import json
from typing import Dict, List, Tuple, Optional

# PyTorch and computer vision
import torch
import torch.nn as nn
import torchvision
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms
from torchvision.utils import make_grid

# Image processing
from PIL import Image, ImageStat
import cv2

# Dataset handling
from datasets import load_dataset
import albumentations as A
from albumentations.pytorch import ToTensorV2

# Progress bars and utilities
from tqdm.auto import tqdm
import time
from collections import Counter

# Set random seeds for reproducibility
def set_seed(seed=42):
    """Set random seeds for reproducibility"""
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)

# Device configuration - optimized for Mac M4 and Colab
def get_device():
    """Get the best available device (CUDA > MPS > CPU)"""
    if torch.cuda.is_available():
        device = torch.device('cuda')
        print(f"🚀 Using CUDA: {torch.cuda.get_device_name(0)}")
        print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
        device = torch.device('mps')
        print(f"🍎 Using MPS: Apple Silicon acceleration")
    else:
        device = torch.device('cpu')
        print(f"💻 Using CPU")
        if platform == "colab":
            print("💡 Enable GPU in Runtime > Change runtime type")
    return device

device = get_device()

# Set style for plots
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

# Platform-specific configurations
if platform == "colab":
    # Colab optimizations
    os.environ['WANDB_SILENT'] = 'true'  # Suppress wandb warnings
    torch.backends.cudnn.benchmark = True  # Optimize for consistent input sizes
    
print(f"✅ Environment setup complete for {platform}!")
print(f"🎯 Device: {device}")
print(f"🐍 Python: {sys.version.split()[0]}")
print(f"🔥 PyTorch: {torch.__version__}")

# %% [markdown]
# ## 🔍 Dataset Loading and Exploration
#
# ### Dataset Information
# - **Source:** Hugging Face - AI-Generated-vs-Real-Images-Datasets
# - **URL:** https://huggingface.co/datasets/Hemg/AI-Generated-vs-Real-Images-Datasets
# - **Task:** Binary classification (Real vs AI-generated)
# - **Content:** Diverse images including people, objects, scenery

# %%
# Configure data directories
DATA_DIR = Path("../data")
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
SPLITS_DIR = DATA_DIR / "splits"

# Create directories
for dir_path in [DATA_DIR, RAW_DIR, PROCESSED_DIR, SPLITS_DIR]:
    dir_path.mkdir(parents=True, exist_ok=True)

print(f"Data directory structure:")
print(f"📁 {DATA_DIR}")
print(f"  📁 {RAW_DIR.name}/")
print(f"  📁 {PROCESSED_DIR.name}/")
print(f"  📁 {SPLITS_DIR.name}/")

# Dataset configuration
DATASET_NAME = "Hemg/AI-Generated-vs-Real-Images-Datasets"
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
